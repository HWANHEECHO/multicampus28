# %%
import requests
import pandas as pd
import json
import lxml
import xmltodict

# 단위: 2017.11 = 100.0
serviceKey = 'YMmU0NmUzNzRiYjY5MWIwOTVjNjE0YTFhYzQ3ZTlhMmQ'
url = 'https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MmU0NmUzNzRiYjY5MWIwOTVjNjE0YTFhYzQ3ZTlhMmQ=&itmId=sales+&objL1=a0+a7+b1+b2+a9+b3+b4+b5+b6+a8+c1+c2+c3+c4+c5+c6+c7+c8+&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&startPrdDe=201711&endPrdDe=202306&orgId=101&tblId=DT_1YL20171E'
req = requests.get(url)
total = pd.DataFrame(req.json())
total
# Out:
#                    TBL_NM  PRD_DE        TBL_ID     ITM_NM ITM_ID ORG_ID  \
# 0     아파트전세가격지수(시도/시/군/구)  201711  DT_1YL20171E  아파트전세가격지수  sales    101
# 1     아파트전세가격지수(시도/시/군/구)  201712  DT_1YL20171E  아파트전세가격지수  sales    101
# 2     아파트전세가격지수(시도/시/군/구)  201801  DT_1YL20171E  아파트전세가격지수  sales    101
# 3     아파트전세가격지수(시도/시/군/구)  201802  DT_1YL20171E  아파트전세가격지수  sales    101
# 4     아파트전세가격지수(시도/시/군/구)  201803  DT_1YL20171E  아파트전세가격지수  sales    101
# ...                   ...     ...           ...        ...    ...    ...
# 1219  아파트전세가격지수(시도/시/군/구)  202302  DT_1YL20171E  아파트전세가격지수  sales    101
# 1220  아파트전세가격지수(시도/시/군/구)  202303  DT_1YL20171E  아파트전세가격지수  sales    101
# 1221  아파트전세가격지수(시도/시/군/구)  202304  DT_1YL20171E  아파트전세가격지수  sales    101
# 1222  아파트전세가격지수(시도/시/군/구)  202305  DT_1YL20171E  아파트전세가격지수  sales    101
# 1223  아파트전세가격지수(시도/시/군/구)  202306  DT_1YL20171E  아파트전세가격지수  sales    101
#
#               UNIT_NM      UNIT_NM_ENG C1_OBJ_NM           DT PRD_SE  C1  \
# ...

# %%
# 주간
# 단위: 2021.6.28=100.0

serviceKey = 'YMmU0NmUzNzRiYjY5MWIwOTVjNjE0YTFhYzQ3ZTlhMmQ'
url = 'https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MmU0NmUzNzRiYjY5MWIwOTVjNjE0YTFhYzQ3ZTlhMmQ=&itmId=T001+&objL1=a0+a1+a2+d1+a4+d2+a6+a7+a8+a9+b1+b2+b3+b4+b5+b6+c1+c2+c3+c4+c5+c6+c7+c8+&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=D&startPrdDe=20210705&endPrdDe=20230724&orgId=408&tblId=DT_304004_WEEK_004'
req = requests.get(url)
weekly = pd.DataFrame(req.json())
weekly
# Out:
#              TBL_NM    PRD_DE              TBL_ID  ITM_NM ITM_ID  \
# 0     주간 아파트 전세가격지수  20210705  DT_304004_WEEK_004  전세가격지수   T001
# 1     주간 아파트 전세가격지수  20210712  DT_304004_WEEK_004  전세가격지수   T001
# 2     주간 아파트 전세가격지수  20210719  DT_304004_WEEK_004  전세가격지수   T001
# 3     주간 아파트 전세가격지수  20210726  DT_304004_WEEK_004  전세가격지수   T001
# 4     주간 아파트 전세가격지수  20210802  DT_304004_WEEK_004  전세가격지수   T001
# ...             ...       ...                 ...     ...    ...
# 2587  주간 아파트 전세가격지수  20230626  DT_304004_WEEK_004  전세가격지수   T001
# 2588  주간 아파트 전세가격지수  20230703  DT_304004_WEEK_004  전세가격지수   T001
# 2589  주간 아파트 전세가격지수  20230710  DT_304004_WEEK_004  전세가격지수   T001
# 2590  주간 아파트 전세가격지수  20230717  DT_304004_WEEK_004  전세가격지수   T001
# 2591  주간 아파트 전세가격지수  20230724  DT_304004_WEEK_004  전세가격지수   T001
#
#               UNIT_NM ORG_ID      UNIT_NM_ENG C1_OBJ_NM C1_OBJ_NM_ENG  \
# 0     2021.6.28＝100.0    408  2021.6.28＝100.0       지역별        Region
# ...

# %%
# 주간 규모별
# 단위: 2021.6.28=100.0

serviceKey = 'YMmU0NmUzNzRiYjY5MWIwOTVjNjE0YTFhYzQ3ZTlhMmQ'
url = 'https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MmU0NmUzNzRiYjY5MWIwOTVjNjE0YTFhYzQ3ZTlhMmQ=&itmId=T001+&objL1=a0+a1+a2+a22+a3+a23+a4+a5+a6+a7+a8+a9+a10+a11+a12+a13+a14+a15+a16+a17+a18+a19+a20+a21+&objL2=01+02+03+04+05+06+&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=D&startPrdDe=20210705&endPrdDe=20230724&orgId=408&tblId=DT_304004_WEEK_008'
req = requests.get(url)
size_weekly = pd.DataFrame(req.json())
size_weekly
# Out:
#                   TBL_NM    PRD_DE              TBL_ID  ITM_NM ITM_ID  \
# 0      주간 규모별 아파트 전세가격지수  20210705  DT_304004_WEEK_008  전세가격지수   T001
# 1      주간 규모별 아파트 전세가격지수  20210712  DT_304004_WEEK_008  전세가격지수   T001
# 2      주간 규모별 아파트 전세가격지수  20210719  DT_304004_WEEK_008  전세가격지수   T001
# 3      주간 규모별 아파트 전세가격지수  20210726  DT_304004_WEEK_008  전세가격지수   T001
# 4      주간 규모별 아파트 전세가격지수  20210802  DT_304004_WEEK_008  전세가격지수   T001
# ...                  ...       ...                 ...     ...    ...
# 15547  주간 규모별 아파트 전세가격지수  20230626  DT_304004_WEEK_008  전세가격지수   T001
# 15548  주간 규모별 아파트 전세가격지수  20230703  DT_304004_WEEK_008  전세가격지수   T001
# 15549  주간 규모별 아파트 전세가격지수  20230710  DT_304004_WEEK_008  전세가격지수   T001
# 15550  주간 규모별 아파트 전세가격지수  20230717  DT_304004_WEEK_008  전세가격지수   T001
# 15551  주간 규모별 아파트 전세가격지수  20230724  DT_304004_WEEK_008  전세가격지수   T001
#
#                UNIT_NM ORG_ID      UNIT_NM_ENG C1_OBJ_NM C1_OBJ_NM_ENG  \
# ...
